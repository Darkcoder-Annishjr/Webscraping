# %% [markdown]
# <a href="https://colab.research.google.com/github/Darkcoder-Annishjr/Webscraping/blob/main/Web-Scraping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup as bs


#Requesting to get the Amazon URL and saving it has response
response = requests.get("https://www.amazon.in/s?i=electronics&bbn=1389401031&rh=n%3A976419031%2Cp_89%3AApple&dc&ds=v1%3AVykN3ePeKgAkQxfea9rZYOxtIdS%2Bg3JznS82Av2dbLM&qid=1713340541&ref=sr_ex_n_1")
response


#Displaying all the Content from the given URL
response.content
# Out:
# b'<!doctype html><html lang="en-in" class="a-no-js" data-19ax5a9jf="dingo"><!-- sp:feature:head-start -->\n<head><script>var aPageStart = (new Date()).getTime();</script><meta charset="utf-8"/>\n<!-- sp:end-feature:head-start -->\n<!-- sp:feature:csm:head-open-part1 -->\n\n<!-- sp:end-feature:csm:head-open-part1 -->\n<!-- sp:feature:cs-optimization -->\n<meta http-equiv=\'x-dns-prefetch-control\' content=\'on\'>\n<link rel="dns-prefetch" href="https://images-eu.ssl-images-amazon.com" crossorigin>\n<link rel="preconnect" href="https://images-eu.ssl-images-amazon.com" crossorigin>\n<link rel="dns-prefetch" href="https://m.media-amazon.com" crossorigin>\n<link rel="preconnect" href="https://m.media-amazon.com" crossorigin>\n<link rel="dns-prefetch" href="https://completion.amazon.com" crossorigin>\n<link rel="preconnect" href="https://completion.amazon.com" crossorigin>\n<!-- sp:end-feature:cs-optimization -->\n<!-- sp:feature:csm:head-open-part2 -->\n\n<!-- sp:end-feature:csm:head-open
# ...

# %%
#Displaying all the content from the URL in HTML
soup = bs(response.content,"html.parser")
soup
# Out:
# <!DOCTYPE html>
# <html class="a-no-js" data-19ax5a9jf="dingo" lang="en-in"><!-- sp:feature:head-start -->
# <head><script>var aPageStart = (new Date()).getTime();</script><meta charset="utf-8"/>
# <!-- sp:end-feature:head-start -->
# <!-- sp:feature:csm:head-open-part1 -->
# <!-- sp:end-feature:csm:head-open-part1 -->
# <!-- sp:feature:cs-optimization -->
# <meta content="on" http-equiv="x-dns-prefetch-control"/>
# <link crossorigin="" href="https://images-eu.ssl-images-amazon.com" rel="dns-prefetch"/>
# <link crossorigin="" href="https://images-eu.ssl-images-amazon.com" rel="preconnect"/>
# <link crossorigin="" href="https://m.media-amazon.com" rel="dns-prefetch"/>
# <link crossorigin="" href="https://m.media-amazon.com" rel="preconnect"/>
# <link crossorigin="" href="https://completion.amazon.com" rel="dns-prefetch"/>
# <link crossorigin="" href="https://completion.amazon.com" rel="preconnect"/>
# <!-- sp:end-feature:cs-optimization -->
# <!-- sp:feature:csm:head-open-part2 -->
# ...

# %%
#Display all the Appple phones from the Amazon names
phones = soup.find_all("span", {"class":"a-size-base-plus a-color-base a-text-normal"})
phones
# Out:
# [<span class="a-size-base-plus a-color-base a-text-normal">Apple Wired EarPods with Lightning Connector</span>,
#  <span class="a-size-base-plus a-color-base a-text-normal">Apple iPhone 15 (128 GB) - Black</span>,
#  <span class="a-size-base-plus a-color-base a-text-normal">Apple iPhone 13 (128GB) - Blue</span>,
#  <span class="a-size-base-plus a-color-base a-text-normal">Apple iPhone 13 (128GB) - Midnight</span>,
#  <span class="a-size-base-plus a-color-base a-text-normal">Apple iPhone 15 (128 GB) - Blue</span>,
#  <span class="a-size-base-plus a-color-base a-text-normal">New Apple AirTag</span>,
#  <span class="a-size-base-plus a-color-base a-text-normal">Apple USB-C to 3.5 mm Headphone Jack Adapter</span>,
#  <span class="a-size-base-plus a-color-base a-text-normal">Apple Watch SE (2nd Gen) [GPS 40 mm] Smart Watch w/Starlight Aluminium Case &amp; Starllight Sport Band. Fitness &amp; Sleep Tracker, Crash Detection, Heart Rate Monitor, Retina Display, Water Resistant</span>,
# ...

# %%
#Print all the Phone names in a list
phones_name = [i.text for i in phones]
phones_name
# Out:
# ['Apple Wired EarPods with Lightning Connector',
#  'Apple iPhone 15 (128 GB) - Black',
#  'Apple iPhone 13 (128GB) - Blue',
#  'Apple iPhone 13 (128GB) - Midnight',
#  'Apple iPhone 15 (128 GB) - Blue',
#  'New Apple AirTag',
#  'Apple USB-C to 3.5 mm Headphone Jack Adapter',
#  'Apple Watch SE (2nd Gen) [GPS 40 mm] Smart Watch w/Starlight Aluminium Case & Starllight Sport Band. Fitness & Sleep Tracker, Crash Detection, Heart Rate Monitor, Retina Display, Water Resistant',
#  'Apple Pencil (2nd Generation) \u200b\u200b\u200b\u200b\u200b\u200b\u200b',
#  'Apple iPhone 14 (128 GB) - Blue',
#  'Apple iPhone 15 (256 GB) - Black',
#  'Apple USB-C to Lightning Cable -2m (for iPhone, iPad, AirPods or iPod with Lightning Connector)',
#  'Apple iPhone 14 (128 GB) - Midnight',
#  'Apple iPhone 15 (128 GB) - Pink',
#  'Apple MagSafe Charger (for iPhone, AirPods Pro, AirPods with Wireless Charging Case)',
#  'Apple iPhone 15 Plus (128 GB) - Blue',
# ...

# %%
#Display all the Appple phones prices from the Amazon
price = soup.find_all("span", {"class":"a-price-whole"})
price
# Out:
# [<span class="a-price-whole">1,799</span>,
#  <span class="a-price-whole">71,590</span>,
#  <span class="a-price-whole">52,090</span>,
#  <span class="a-price-whole">52,090</span>,
#  <span class="a-price-whole">71,590</span>,
#  <span class="a-price-whole">3,490</span>,
#  <span class="a-price-whole">900</span>,
#  <span class="a-price-whole">23,900</span>,
#  <span class="a-price-whole">11,499</span>,
#  <span class="a-price-whole">58,999</span>,
#  <span class="a-price-whole">81,990</span>,
#  <span class="a-price-whole">2,900</span>,
#  <span class="a-price-whole">58,999</span>,
#  <span class="a-price-whole">71,590</span>,
#  <span class="a-price-whole">3,849</span>,
#  <span class="a-price-whole">80,990</span>,
#  <span class="a-price-whole">26,499</span>,
#  <span class="a-price-whole">71,590</span>,
#  <span class="a-price-whole">58,999</span>,
#  <span class="a-price-whole">81,990</span>,
#  <span class="a-price-whole">1,823</span>,
# ...

# %%
#Print all the Phone names in a list
price_of_phones = [i.text for i in price]
price_of_phones
# Out:
# ['1,799',
#  '71,590',
#  '52,090',
#  '52,090',
#  '71,590',
#  '3,490',
#  '900',
#  '23,900',
#  '11,499',
#  '58,999',
#  '81,990',
#  '2,900',
#  '58,999',
#  '71,590',
#  '3,849',
#  '80,990',
#  '26,499',
#  '71,590',
#  '58,999',
#  '81,990',
#  '1,823',
#  '80,990',
#  '7,399',
#  '1,48,900']

# %%
#Display the both phones_name and price_of_phones
display(phones_name, price_of_phones)
# Out:
# ['Apple Wired EarPods with Lightning Connector',
#  'Apple iPhone 15 (128 GB) - Black',
#  'Apple iPhone 13 (128GB) - Blue',
#  'Apple iPhone 13 (128GB) - Midnight',
#  'Apple iPhone 15 (128 GB) - Blue',
#  'New Apple AirTag',
#  'Apple USB-C to 3.5 mm Headphone Jack Adapter',
#  'Apple Watch SE (2nd Gen) [GPS 40 mm] Smart Watch w/Starlight Aluminium Case & Starllight Sport Band. Fitness & Sleep Tracker, Crash Detection, Heart Rate Monitor, Retina Display, Water Resistant',
#  'Apple Pencil (2nd Generation) \u200b\u200b\u200b\u200b\u200b\u200b\u200b',
#  'Apple iPhone 14 (128 GB) - Blue',
#  'Apple iPhone 15 (256 GB) - Black',
#  'Apple USB-C to Lightning Cable -2m (for iPhone, iPad, AirPods or iPod with Lightning Connector)',
#  'Apple iPhone 14 (128 GB) - Midnight',
#  'Apple iPhone 15 (128 GB) - Pink',
#  'Apple MagSafe Charger (for iPhone, AirPods Pro, AirPods with Wireless Charging Case)',
#  'Apple iPhone 15 Plus (128 GB) - Blue',
# ...

# %%
#Saving this information in a variable called data
data = {"Apple Phones": phones_name,"Apple_phones_price" : price_of_phones}
data
# Out:
# {'Apple Phones': ['Apple Wired EarPods with Lightning Connector',
#   'Apple iPhone 15 (128 GB) - Black',
#   'Apple iPhone 13 (128GB) - Blue',
#   'Apple iPhone 13 (128GB) - Midnight',
#   'Apple iPhone 15 (128 GB) - Blue',
#   'New Apple AirTag',
#   'Apple USB-C to 3.5 mm Headphone Jack Adapter',
#   'Apple Watch SE (2nd Gen) [GPS 40 mm] Smart Watch w/Starlight Aluminium Case & Starllight Sport Band. Fitness & Sleep Tracker, Crash Detection, Heart Rate Monitor, Retina Display, Water Resistant',
#   'Apple Pencil (2nd Generation) \u200b\u200b\u200b\u200b\u200b\u200b\u200b',
#   'Apple iPhone 14 (128 GB) - Blue',
#   'Apple iPhone 15 (256 GB) - Black',
#   'Apple USB-C to Lightning Cable -2m (for iPhone, iPad, AirPods or iPod with Lightning Connector)',
#   'Apple iPhone 14 (128 GB) - Midnight',
#   'Apple iPhone 15 (128 GB) - Pink',
#   'Apple MagSafe Charger (for iPhone, AirPods Pro, AirPods with Wireless Charging Case)',
#   'Apple iPhone 15 Plus (128 GB) - Blue',
# ...

# %%
#Now we gonna use pandas to view in a data frame
df = pd.DataFrame(data)
df
# Out:
#                                          Apple Phones Apple_phones_price
# 0        Apple Wired EarPods with Lightning Connector              1,799
# 1                    Apple iPhone 15 (128 GB) - Black             71,590
# 2                      Apple iPhone 13 (128GB) - Blue             52,090
# 3                  Apple iPhone 13 (128GB) - Midnight             52,090
# 4                     Apple iPhone 15 (128 GB) - Blue             71,590
# 5                                    New Apple AirTag              3,490
# 6        Apple USB-C to 3.5 mm Headphone Jack Adapter                900
# 7   Apple Watch SE (2nd Gen) [GPS 40 mm] Smart Wat...             23,900
# 8               Apple Pencil (2nd Generation) ​​​​​​​             11,499
# 9                     Apple iPhone 14 (128 GB) - Blue             58,999
# 10                   Apple iPhone 15 (256 GB) - Black             81,990
# 11  Apple USB-C to Lightning Cable -2m (for iPhone...              2,900
# ...

# %%
#You can save this information in any format you want csv,xlsx,json etc..
df.to_csv("Amazon_Apple_Phones.csv")
